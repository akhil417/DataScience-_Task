# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
import warnings 
warnings.filterwarnings("ignore")
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor

# %%
train = pd.read_csv("C:\\Users\\bakhil\\Documents\\Data Science\\DS Task\\BlackFriday\\train.csv")
train.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
test = pd.read_csv("C:\\Users\\bakhil\\Documents\\Data Science\\DS Task\\BlackFriday\\test.csv")
test.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# ...

# %%
sample = pd.read_csv("C:\\Users\\bakhil\\Documents\\Data Science\\DS Task\\BlackFriday\\sample_submission_V9Inaty.csv")
sample.head()
# Out:
#    Purchase  User_ID Product_ID
# 0       100  1000004  P00128942
# 1       100  1000009  P00113442
# 2       100  1000010  P00288442
# 3       100  1000010  P00145342
# 4       100  1000011  P00053842

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
train.describe().T
# Out:
#                        count          mean          std        min        25%  \
# User_ID             550068.0  1.003029e+06  1727.591586  1000001.0  1001516.0
# Occupation          550068.0  8.076707e+00     6.522660        0.0        2.0
# Marital_Status      550068.0  4.096530e-01     0.491770        0.0        0.0
# Product_Category_1  550068.0  5.404270e+00     3.936211        1.0        1.0
# Product_Category_2  376430.0  9.842329e+00     5.086590        2.0        5.0
# Product_Category_3  166821.0  1.266824e+01     4.125338        3.0        9.0
# Purchase            550068.0  9.263969e+03  5023.065394       12.0     5823.0
#
#                           50%        75%        max
# User_ID             1003077.0  1004478.0  1006040.0
# Occupation                7.0       14.0       20.0
# Marital_Status            0.0        1.0        1.0
# Product_Category_1        5.0        8.0       20.0
# Product_Category_2        9.0       15.0       18.0
# ...

# %%
train.shape,test.shape
# Out:
# ((550068, 12), (233599, 11))

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233599 entries, 0 to 233598
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     233599 non-null  int64
#  1   Product_ID                  233599 non-null  object
#  2   Gender                      233599 non-null  object
#  3   Age                         233599 non-null  object
#  4   Occupation                  233599 non-null  int64
#  5   City_Category               233599 non-null  object
#  6   Stay_In_Current_City_Years  233599 non-null  object
#  7   Marital_Status              233599 non-null  int64
#  8   Product_Category_1          233599 non-null  int64
#  9   Product_Category_2          161255 non-null  float64
#  10  Product_Category_3          71037 non-null   float64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 19.6+ MB

# %%
test.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  2.335990e+05  233599.000000   233599.000000       233599.000000
# mean   1.003029e+06       8.085407        0.410070            5.276542
# std    1.726505e+03       6.521146        0.491847            3.736380
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001527e+06       2.000000        0.000000            1.000000
# 50%    1.003070e+06       7.000000        0.000000            5.000000
# 75%    1.004477e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           18.000000
#
#        Product_Category_2  Product_Category_3
# count       161255.000000        71037.000000
# mean             9.849586           12.669454
# std              5.094943            4.125944
# min              2.000000            3.000000
# 25%              5.000000            9.000000
# 50%              9.000000           14.000000
# ...

# %%
train['Source'] = 'Train'
test['Source'] = 'Test'

# %%
train.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase Source
# 0                 NaN                 NaN      8370  Train
# 1                 6.0                14.0     15200  Train
# ...

# %%
test.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3 Source
# 0                11.0                 NaN   Test
# 1                 5.0                 NaN   Test
# 2                14.0                 NaN   Test
# ...

# %%
df = pd.concat([train,test])
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase Source
# 0                 NaN                 NaN    8370.0  Train
# 1                 6.0                14.0   15200.0  Train
# ...

# %%
df.tail()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 233594                         4+               1                   8
# 233595                         4+               1                   5
# 233596                         4+               1                   1
# 233597                         4+               0                  10
# 233598                         4+               1                   4
#
#         Product_Category_2  Product_Category_3  Purchase Source
# 233594                 NaN                 NaN       NaN   Test
# ...

# %%
train.isna().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# Source                             0
# dtype: int64

# %%
test.isna().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2             72344
# Product_Category_3            162562
# Source                             0
# dtype: int64

# %%
train['Age'].value_counts()
# Out:
# 26-35    219587
# 36-45    110013
# 18-25     99660
# 46-50     45701
# 51-55     38501
# 55+       21504
# 0-17      15102
# Name: Age, dtype: int64

# %%
Numeracial_Columns = df.select_dtypes(include=np.number).drop(columns = ['Purchase','User_ID'])
Numeracial_Columns
# Out:
#         Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# 0               10               0                   3                 NaN
# 1               10               0                   1                 6.0
# 2               10               0                  12                 NaN
# 3               10               0                  12                14.0
# 4               16               0                   8                 NaN
# ...            ...             ...                 ...                 ...
# 233594          15               1                   8                 NaN
# 233595          15               1                   5                 8.0
# 233596          15               1                   1                 5.0
# 233597           1               0                  10                16.0
# 233598           0               1                   4                 5.0
#
#         Product_Category_3
# 0                      NaN
# ...

# %%
Categorical_columns = df.select_dtypes(exclude=np.number)
Categorical_columns
# Out:
#        Product_ID Gender    Age City_Category Stay_In_Current_City_Years  \
# 0       P00069042      F   0-17             A                          2
# 1       P00248942      F   0-17             A                          2
# 2       P00087842      F   0-17             A                          2
# 3       P00085442      F   0-17             A                          2
# 4       P00285442      M    55+             C                         4+
# ...           ...    ...    ...           ...                        ...
# 233594  P00118942      F  26-35             B                         4+
# 233595  P00254642      F  26-35             B                         4+
# 233596  P00031842      F  26-35             B                         4+
# 233597  P00124742      F  46-50             C                         4+
# 233598  P00316642      F  46-50             B                         4+
#
#        Source
# 0       Train
# 1       Train
# 2       Train
# 3       Train
# ...

# %%
Categorical_columns.apply(lambda x:x.nunique())
# Out:
# Product_ID                    3677
# Gender                           2
# Age                              7
# City_Category                    3
# Stay_In_Current_City_Years       5
# Source                           2
# dtype: int64

# %%
Categorical_columns.apply(lambda x:print(x.value_counts()))
# Out:
# P00265242    2709
# P00025442    2310
# P00110742    2292
# P00112142    2279
# P00046742    2084
#              ...
# P00312642       1
# P00143242       1
# P00072142       1
# P00306542       1
# P00091542       1
# Name: Product_ID, Length: 3677, dtype: int64
# M    590031
# F    193636
# Name: Gender, dtype: int64
# 26-35    313015
# 36-45    156724
# 18-25    141953
# 46-50     65278
# 51-55     54784
# 55+       30579
# 0-17      21334
# Name: Age, dtype: int64
# B    329739
# C    243684
# A    210244
# Name: City_Category, dtype: int64
# 1     276425
# 2     145427
# 3     135428
# 4+    120671
# 0     105716
# Name: Stay_In_Current_City_Years, dtype: int64
# Train    550068
# Test     233599
# Name: Source, dtype: int64
# Product_ID                    None
# Gender                        None
# Age                           None
# City_Category                 None
# Stay_In_Current_City_Years    None
# Source                        None
# dtype: object

# %%
df['Product_ID'].value_counts()
# Out:
# P00265242    2709
# P00025442    2310
# P00110742    2292
# P00112142    2279
# P00046742    2084
#              ...
# P00312642       1
# P00143242       1
# P00072142       1
# P00306542       1
# P00091542       1
# Name: Product_ID, Length: 3677, dtype: int64

# %%
df['Product_ID'] = df['Product_ID'].str.replace('P00','')

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001     069042      F  0-17          10             A
# 1  1000001     248942      F  0-17          10             A
# 2  1000001     087842      F  0-17          10             A
# 3  1000001     085442      F  0-17          10             A
# 4  1000002     285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase Source
# 0                 NaN                 NaN    8370.0  Train
# 1                 6.0                14.0   15200.0  Train
# ...

# %%
df['Product_ID'].value_counts()
# Out:
# 265242    2709
# 025442    2310
# 110742    2292
# 112142    2279
# 046742    2084
#           ...
# 241842       1
# 038842       1
# 053242       1
# 030342       1
# 166542       1
# Name: Product_ID, Length: 3677, dtype: int64

# %%
one_hot_encoded_data = pd.get_dummies(df, columns = ['City_Category', 'Gender'])

# %%
one_hot_encoded_data
# Out:
#         User_ID Product_ID    Age  Occupation Stay_In_Current_City_Years  \
# 0       1000001     069042   0-17          10                          2
# 1       1000001     248942   0-17          10                          2
# 2       1000001     087842   0-17          10                          2
# 3       1000001     085442   0-17          10                          2
# 4       1000002     285442    55+          16                         4+
# ...         ...        ...    ...         ...                        ...
# 233594  1006036     118942  26-35          15                         4+
# 233595  1006036     254642  26-35          15                         4+
# 233596  1006036     031842  26-35          15                         4+
# 233597  1006037     124742  46-50           1                         4+
# 233598  1006039     316642  46-50           0                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
one_hot_encoded_data['Age']=one_hot_encoded_data['Age'].replace('0-17',17)
one_hot_encoded_data['Age']=one_hot_encoded_data['Age'].replace('18-25',25)
one_hot_encoded_data['Age']=one_hot_encoded_data['Age'].replace('26-35',35)
one_hot_encoded_data['Age']=one_hot_encoded_data['Age'].replace('36-45',45)
one_hot_encoded_data['Age']=one_hot_encoded_data['Age'].replace('46-50',50)
one_hot_encoded_data['Age']=one_hot_encoded_data['Age'].replace('51-55',55)
one_hot_encoded_data['Age']=one_hot_encoded_data['Age'].replace('55+',60)

# %%
one_hot_encoded_data
# Out:
#         User_ID Product_ID  Age  Occupation Stay_In_Current_City_Years  \
# 0       1000001     069042   17          10                          2
# 1       1000001     248942   17          10                          2
# 2       1000001     087842   17          10                          2
# 3       1000001     085442   17          10                          2
# 4       1000002     285442   60          16                         4+
# ...         ...        ...  ...         ...                        ...
# 233594  1006036     118942   35          15                         4+
# 233595  1006036     254642   35          15                         4+
# 233596  1006036     031842   35          15                         4+
# 233597  1006037     124742   50           1                         4+
# 233598  1006039     316642   50           0                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
one_hot_encoded_data['Stay_In_Current_City_Years']=one_hot_encoded_data['Stay_In_Current_City_Years'].replace('4+',4)

# %%
one_hot_encoded_data
# Out:
#         User_ID Product_ID  Age  Occupation Stay_In_Current_City_Years  \
# 0       1000001     069042   17          10                          2
# 1       1000001     248942   17          10                          2
# 2       1000001     087842   17          10                          2
# 3       1000001     085442   17          10                          2
# 4       1000002     285442   60          16                          4
# ...         ...        ...  ...         ...                        ...
# 233594  1006036     118942   35          15                          4
# 233595  1006036     254642   35          15                          4
# 233596  1006036     031842   35          15                          4
# 233597  1006037     124742   50           1                          4
# 233598  1006039     316642   50           0                          4
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
one_hot_encoded_data.shape
# Out:
# (783667, 16)

# %%
data = one_hot_encoded_data

# %%
one_hot_encoded_data
# Out:
#         User_ID Product_ID  Age  Occupation Stay_In_Current_City_Years  \
# 0       1000001     069042   17          10                          2
# 1       1000001     248942   17          10                          2
# 2       1000001     087842   17          10                          2
# 3       1000001     085442   17          10                          2
# 4       1000002     285442   60          16                          4
# ...         ...        ...  ...         ...                        ...
# 233594  1006036     118942   35          15                          4
# 233595  1006036     254642   35          15                          4
# 233596  1006036     031842   35          15                          4
# 233597  1006037     124742   50           1                          4
# 233598  1006039     316642   50           0                          4
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
data
# Out:
#         User_ID Product_ID  Age  Occupation Stay_In_Current_City_Years  \
# 0       1000001     069042   17          10                          2
# 1       1000001     248942   17          10                          2
# 2       1000001     087842   17          10                          2
# 3       1000001     085442   17          10                          2
# 4       1000002     285442   60          16                          4
# ...         ...        ...  ...         ...                        ...
# 233594  1006036     118942   35          15                          4
# 233595  1006036     254642   35          15                          4
# 233596  1006036     031842   35          15                          4
# 233597  1006037     124742   50           1                          4
# 233598  1006039     316642   50           0                          4
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
data1 = data.drop(['User_ID','Product_ID','Purchase'],axis=1)

# %%
data1
# Out:
#         Age  Occupation Stay_In_Current_City_Years  Marital_Status  \
# 0        17          10                          2               0
# 1        17          10                          2               0
# 2        17          10                          2               0
# 3        17          10                          2               0
# 4        60          16                          4               0
# ...     ...         ...                        ...             ...
# 233594   35          15                          4               1
# 233595   35          15                          4               1
# 233596   35          15                          4               1
# 233597   50           1                          4               0
# 233598   50           0                          4               1
#
#         Product_Category_1  Product_Category_2  Product_Category_3 Source  \
# 0                        3                 NaN                 NaN  Train
# ...

# %%
data
# Out:
#         User_ID Product_ID  Age  Occupation Stay_In_Current_City_Years  \
# 0       1000001     069042   17          10                          2
# 1       1000001     248942   17          10                          2
# 2       1000001     087842   17          10                          2
# 3       1000001     085442   17          10                          2
# 4       1000002     285442   60          16                          4
# ...         ...        ...  ...         ...                        ...
# 233594  1006036     118942   35          15                          4
# 233595  1006036     254642   35          15                          4
# 233596  1006036     031842   35          15                          4
# 233597  1006037     124742   50           1                          4
# 233598  1006039     316642   50           0                          4
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
data1.boxplot(column = 'Product_Category_3')
# Out:
# <AxesSubplot:>

# %%
data1.boxplot(column = 'Product_Category_2')
# Out:
# <AxesSubplot:>

# %%
#No Outlayers so we can fill mean in both Product_Category_2 and Product_Category_3 columns

# %%
data1.isna().sum()
# Out:
# Age                                0
# Occupation                         0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            245982
# Product_Category_3            545809
# Source                             0
# City_Category_A                    0
# City_Category_B                    0
# City_Category_C                    0
# Gender_F                           0
# Gender_M                           0
# dtype: int64

# %%
data1['Product_Category_2'] = data1.groupby(['Age','Occupation','Stay_In_Current_City_Years']).Product_Category_2.transform(lambda x: x.fillna(x.mean()))

# %%
data1.isna().sum()
# Out:
# Age                                0
# Occupation                         0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2                 0
# Product_Category_3            545809
# Source                             0
# City_Category_A                    0
# City_Category_B                    0
# City_Category_C                    0
# Gender_F                           0
# Gender_M                           0
# dtype: int64

# %%
data1['Product_Category_3'] = data1.groupby(['Age','Occupation','Stay_In_Current_City_Years']).Product_Category_3.transform(lambda x: x.fillna(x.mean()))

# %%
data1.isna().sum()
# Out:
# Age                            0
# Occupation                     0
# Stay_In_Current_City_Years     0
# Marital_Status                 0
# Product_Category_1             0
# Product_Category_2             0
# Product_Category_3            19
# Source                         0
# City_Category_A                0
# City_Category_B                0
# City_Category_C                0
# Gender_F                       0
# Gender_M                       0
# dtype: int64

# %%
data1['Product_Category_3'] = data1.groupby(['Age','Occupation','Stay_In_Current_City_Years']).Product_Category_3.transform(lambda x: x.fillna(x.mean()))

# %%
data1.isna().sum()
# Out:
# Age                            0
# Occupation                     0
# Stay_In_Current_City_Years     0
# Marital_Status                 0
# Product_Category_1             0
# Product_Category_2             0
# Product_Category_3            19
# Source                         0
# City_Category_A                0
# City_Category_B                0
# City_Category_C                0
# Gender_F                       0
# Gender_M                       0
# dtype: int64

# %%
data1['Product_Category_3'] = data1.groupby('Marital_Status').Product_Category_3.transform(lambda x: x.fillna(x.mean()))

# %%
data1.isna().sum()
# Out:
# Age                           0
# Occupation                    0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Source                        0
# City_Category_A               0
# City_Category_B               0
# City_Category_C               0
# Gender_F                      0
# Gender_M                      0
# dtype: int64

# %%
data1.shape
# Out:
# (783667, 13)

# %%
sns.pairplot(data1)

# %%
sns.heatmap(data1.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %%
data2=one_hot_encoded_data.drop(columns = ['Age','Occupation','Stay_In_Current_City_Years','Marital_Status','Product_Category_1','Product_Category_2','Product_Category_3','Source','City_Category_A','City_Category_B','City_Category_C','Gender_F','Gender_M'])

# %%
data1
# Out:
#         Age  Occupation Stay_In_Current_City_Years  Marital_Status  \
# 0        17          10                          2               0
# 1        17          10                          2               0
# 2        17          10                          2               0
# 3        17          10                          2               0
# 4        60          16                          4               0
# ...     ...         ...                        ...             ...
# 233594   35          15                          4               1
# 233595   35          15                          4               1
# 233596   35          15                          4               1
# 233597   50           1                          4               0
# 233598   50           0                          4               1
#
#         Product_Category_1  Product_Category_2  Product_Category_3 Source  \
# 0                        3            8.685950           11.599686  Train
# ...

# %%
data2
# Out:
#         User_ID Product_ID  Purchase
# 0       1000001     069042    8370.0
# 1       1000001     248942   15200.0
# 2       1000001     087842    1422.0
# 3       1000001     085442    1057.0
# 4       1000002     285442    7969.0
# ...         ...        ...       ...
# 233594  1006036     118942       NaN
# 233595  1006036     254642       NaN
# 233596  1006036     031842       NaN
# 233597  1006037     124742       NaN
# 233598  1006039     316642       NaN
#
# [783667 rows x 3 columns]

# %%
horizontal_concat = pd.concat([data1, data2], axis=1)

# %%
horizontal_concat
# Out:
#         Age  Occupation Stay_In_Current_City_Years  Marital_Status  \
# 0        17          10                          2               0
# 1        17          10                          2               0
# 2        17          10                          2               0
# 3        17          10                          2               0
# 4        60          16                          4               0
# ...     ...         ...                        ...             ...
# 233594   35          15                          4               1
# 233595   35          15                          4               1
# 233596   35          15                          4               1
# 233597   50           1                          4               0
# 233598   50           0                          4               1
#
#         Product_Category_1  Product_Category_2  Product_Category_3 Source  \
# 0                        3            8.685950           11.599686  Train
# ...

# %%
horizontal_concat.isna().sum()
# Out:
# Age                                0
# Occupation                         0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2                 0
# Product_Category_3                 0
# Source                             0
# City_Category_A                    0
# City_Category_B                    0
# City_Category_C                    0
# Gender_F                           0
# Gender_M                           0
# User_ID                            0
# Product_ID                         0
# Purchase                      233599
# dtype: int64

# %%
train = horizontal_concat.loc[horizontal_concat['Source']=='Train']
test = horizontal_concat.loc[horizontal_concat['Source']=='Test']

# %%
train.head()
# Out:
#    Age  Occupation Stay_In_Current_City_Years  Marital_Status  \
# 0   17          10                          2               0
# 1   17          10                          2               0
# 2   17          10                          2               0
# 3   17          10                          2               0
# 4   60          16                          4               0
#
#    Product_Category_1  Product_Category_2  Product_Category_3 Source  \
# 0                   3            8.685950           11.599686  Train
# 1                   1            6.000000           14.000000  Train
# 2                  12            8.685950           11.599686  Train
# 3                  12           14.000000           11.599686  Train
# 4                   8           10.450893           13.033708  Train
#
#    City_Category_A  City_Category_B  City_Category_C  Gender_F  Gender_M  \
# 0                1                0                0         1         0
# ...

# %%
train.shape
# Out:
# (550068, 16)

# %%
train.isna().sum()
# Out:
# Age                           0
# Occupation                    0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Source                        0
# City_Category_A               0
# City_Category_B               0
# City_Category_C               0
# Gender_F                      0
# Gender_M                      0
# User_ID                       0
# Product_ID                    0
# Purchase                      0
# dtype: int64

# %%
test.head()
# Out:
#    Age  Occupation Stay_In_Current_City_Years  Marital_Status  \
# 0   50           7                          2               1
# 1   35          17                          0               0
# 2   45           1                          4               1
# 3   45           1                          4               1
# 4   35           1                          1               0
#
#    Product_Category_1  Product_Category_2  Product_Category_3 Source  \
# 0                   1                11.0           12.377834   Test
# 1                   3                 5.0           12.816514   Test
# 2                   5                14.0           12.660131   Test
# 3                   4                 9.0           12.660131   Test
# 4                   4                 5.0           12.000000   Test
#
#    City_Category_A  City_Category_B  City_Category_C  Gender_F  Gender_M  \
# 0                0                1                0         0         1
# ...

# %%
test.shape
# Out:
# (233599, 16)

# %%
test = test.drop(columns =['Purchase'])

# %%
test.shape
# Out:
# (233599, 15)

# %%
test.isna().sum()
# Out:
# Age                           0
# Occupation                    0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Source                        0
# City_Category_A               0
# City_Category_B               0
# City_Category_C               0
# Gender_F                      0
# Gender_M                      0
# User_ID                       0
# Product_ID                    0
# dtype: int64

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
corr_ = train.corr()
sns.heatmap(corr_,annot = True)
# Out:
# <AxesSubplot:>

# %%
X = train.select_dtypes(include=np.number).drop(columns = ['City_Category_A','User_ID','City_Category_B','Gender_F','Gender_M','City_Category_C','Purchase',])

# %%
vif_data = pd.DataFrame()
vif_data['features'] = X.columns
vif_data
# Out:
#              features
# 0                 Age
# 1          Occupation
# 2      Marital_Status
# 3  Product_Category_1
# 4  Product_Category_2
# 5  Product_Category_3

# %%
vif_data['VIF'] = [variance_inflation_factor(X.values,i) for i in range(len(X.columns))]

# %%
vif_data
# Out:
#              features        VIF
# 0                 Age  13.179827
# 1          Occupation   2.516107
# 2      Marital_Status   1.868452
# 3  Product_Category_1   3.347306
# 4  Product_Category_2   8.383195
# 5  Product_Category_3  16.761305
